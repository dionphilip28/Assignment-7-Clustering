# %% [markdown]
# ### Problem Statement: Perform clustering (hierarchical,K means clustering and DBSCAN) for the airlines data to obtain optimum number of clusters.

# %% [markdown]
# ## Hierarchical Clustering

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
airlines = pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')
airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines[airlines.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID#, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?]
# Index: []

# %%
airlines.drop_duplicates(inplace=True)

# %%
airlines.reset_index(inplace=True, drop=True)

# %%
airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data = airlines.copy()
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data.drop('ID#',axis=1,inplace=True)

# %%
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#Normalization function
def min_max(i):
    x = (i-i.min())/(i.max()-i.min())
    return x

# %%
#Normalized dataframe (Considering only numerical part of data)
data_norm = min_max(data.iloc[:,:])

# %%
data_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#Create dendrogram
fig, axes = plt.subplots(figsize=(10, 8))
dendrogram = sch.dendrogram(sch.linkage(data_norm, method='complete'))

# %%
#Create clusters
hc = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')
hc
# Out:
# AgglomerativeClustering(n_clusters=4)

# %%
#Save clusters for charts
y_hc = hc.fit_predict(data_norm)
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])

# %%
y_hc
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
hc.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
data1 = data.copy()
data1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data1['clusterid']=hc.labels_

# %%
data1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data1.groupby('clusterid').agg(['mean']).reset_index()
# Out:
#   clusterid        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                       mean        mean      mean      mean      mean
# 0         0   37876.890058   52.797076  1.000000  1.019883  1.000585
# 1         1   79848.233615  285.097252  1.699789  1.024313  1.000000
# 2         2  106221.111386  161.262376  3.198020  1.001238  1.025990
# 3         3  127475.028037  160.801869  4.362617  1.000000  1.050467
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0   2558.508187    5.730994        239.314035        0.697076
# 1  12079.774841   12.133192        781.939746        2.369979
# 2  26458.257426   16.363861        198.733911        0.558168
# 3  58656.919626   22.235514        991.110280        3.005607
#
#   Days_since_enroll Award?
#                mean   mean
# 0       3562.376608      0
# 1       4372.173362      1
# 2       4367.250000      0
# 3       5072.226168      1

# %%
# Plot Clusters
plt.scatter(data1['clusterid'],data1['Balance'],c=hc.labels_)
plt.show()

# %%
sns.pairplot(data1)

# %% [markdown]
# ## K-Means Clustering

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
array = data.values
array
# Out:
# array([[28143,     0,     1, ...,     0,  7000,     0],
#        [19244,     0,     1, ...,     0,  6968,     0],
#        [41354,     0,     1, ...,     0,  7034,     0],
#        ...,
#        [73597,     0,     3, ...,     0,  1402,     1],
#        [54899,     0,     1, ...,     1,  1401,     0],
#        [ 3016,     0,     1, ...,     0,  1398,     0]], dtype=int64)

# %%
#Normalizing the data
scaler = StandardScaler()
X = scaler.fit_transform(array)

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss,marker='o')
plt.title("Elbow Method")
plt.xlabel('No.of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.metrics import silhouette_score

for i in range(2,11):
    cluster = KMeans(n_clusters=i,random_state=0)
    cluster.fit_predict(X)

    silhouette_avg = silhouette_score(X, cluster.labels_, metric='euclidean')
    print('For no. of clusters =', i, 
           '\nThe average silhouette score is :', silhouette_avg)
# Out:
# For no. of clusters = 2
# The average silhouette score is : 0.3256981835090824
# For no. of clusters = 3
# The average silhouette score is : 0.3121716765282414
# For no. of clusters = 4
# The average silhouette score is : 0.32563311512799126
# For no. of clusters = 5
# The average silhouette score is : 0.31819537664378844
# For no. of clusters = 6
# The average silhouette score is : 0.3338735662323181
# For no. of clusters = 7
# The average silhouette score is : 0.22085896619040385
# For no. of clusters = 8
# The average silhouette score is : 0.23657639934232003
# For no. of clusters = 9
# The average silhouette score is : 0.2984364654012059
# For no. of clusters = 10
# The average silhouette score is : 0.2617650187720957

# %%
#Build KMean algorithm
clusters_new = KMeans(4, random_state=0)
clusters_new.fit(data_norm)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
clusters_new.labels_
# Out:
# array([1, 1, 1, ..., 2, 1, 1])

# %%
clusters_new.cluster_centers_
# Out:
# array([[ 4.89953609e-02,  2.60542873e-02,  3.90044577e-02,
#          1.63447251e-02,  2.22882615e-03,  3.35642727e-02,
#          1.21825219e-01,  3.34267751e-02,  5.94073285e-02,
#          5.22892182e-01,  1.00000000e+00],
#        [ 2.37681325e-02,  8.07125209e-03,  2.24748810e-02,
#          8.98995241e-03,  1.05764146e-03,  1.25750315e-02,
#          7.51540344e-02,  7.35667765e-03,  1.24322760e-02,
#          4.34424062e-01,  3.27515792e-15],
#        [ 6.35352962e-02,  1.77912301e-02,  7.28960396e-01,
#          6.18811881e-04,  6.49752475e-03,  1.72970238e-01,
#          2.34903868e-01,  2.31602349e-02,  4.04212591e-02,
#          5.86139300e-01,  1.00000000e+00],
#        [ 6.92010150e-02,  7.21537510e-03,  6.40350877e-01,
#          7.97448166e-04,  5.58213716e-03,  1.17843075e-01,
#          2.00289307e-01,  7.30214826e-03,  1.19466763e-02,
#          5.38787863e-01, -4.99600361e-16]])

# %%
data2 = data.copy()
data2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data2['k_clusterid'] = clusters_new.labels_

# %%
data2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data2.groupby('k_clusterid').agg(['mean']).reset_index()
# Out:
#   k_clusterid        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                         mean        mean      mean      mean      mean
# 0           0   83529.153046  290.453195  1.156018  1.032689  1.008915
# 1           1   40520.815442   89.978318  1.089900  1.017980  1.004231
# 2           2  108317.387376  198.336634  3.915842  1.001238  1.025990
# 3           3  117976.519936   80.437002  3.561404  1.001595  1.022329
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0   8850.395245   10.476969       1030.112927        3.148588
# 1   3315.847171    6.463247        226.710735        0.658911
# 2  45609.657178   20.201733        713.728960        2.142327
# 3  31073.451356   17.224880        225.030303        0.633174
#
#   Days_since_enroll Award?
#                mean   mean
# 0       4338.867756      1
# 1       3605.113168      0
# 2       4863.439356      1
# ...

# %%
plt.figure(figsize=(5,5))  
plt.scatter(data2['k_clusterid'],data2['Balance'], c=clusters_new.labels_)
plt.show()

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics

# %%
data3 = data.copy()
data3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#Normalized data
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
dbscan = DBSCAN(eps=5, min_samples=8)
dbscan.fit(X)
# Out:
# DBSCAN(eps=5, min_samples=8)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#Silhouette Score
S=metrics.silhouette_score(X,dbscan.labels_)
S
# Out:
# 0.5471214263010564

# %%
data3['Cluster']=pd.DataFrame(dbscan.labels_)

# %%
data3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data3['Cluster'].value_counts()
# Out:
#  0    3931
#  2      28
# -1      25
#  1      15
# Name: Cluster, dtype: int64

# %%
plt.figure(figsize=(5,5))  
plt.scatter(data3['Cluster'],data3['Balance'], c=dbscan.labels_)
plt.show()
